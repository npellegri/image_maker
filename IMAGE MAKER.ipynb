# %%
# Install CPU-compatible versions (you can skip the CUDA line)
# %pip install diffusers
# %pip install ipywidgets
# %pip install accelerate
# %pip install torch torchvision torchaudio
# %pip install transformers

from diffusers import StableDiffusionPipeline
import torch
from IPython.display import display

# Check if CUDA (GPU) is available, else fall back to CPU
device = "cuda" if torch.cuda.is_available() else "cpu"

# Use "mps" if on Apple Silicon (M1/M2), or "cpu" if Intel Mac
#device = "cpu" if torch.backends.mps.is_available() else "mps"

pipe = StableDiffusionPipeline.from_pretrained("dreamlike-art/dreamlike-photoreal-2.0").to(device)
pipe = pipe.to(device)
pipe.enable_attention_slicing()  # Reduce memory usage by enabling attention slicing

prompts = [
    "Dean Winchester from TV Show Supernatural with Demon Eyes in a Hell background"
]

images = [pipe(prompt, guidance_scale=9).images[0] for prompt in prompts]
for i, image in enumerate(images):
    image.save(f"output_{i}.png")
    display(image)
# Out:
# Requirement already satisfied: diffusers in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (0.33.1)
# Requirement already satisfied: importlib-metadata in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (8.6.1)
# Requirement already satisfied: filelock in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (0.30.2)
# Requirement already satisfied: numpy in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (2.1.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from diffusers) (11.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.27.0->diffusers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.27.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.27.0->diffusers) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\pelle\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.27.0->diffusers) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (8.1.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipywidgets) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: colorama in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\pelle\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\pelle\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in c:\users\pelle\appdata\roaming\python\python311\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (2.6.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pelle\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (0.21.0)
# Requirement already satisfied: torchaudio in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (2.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (4.51.3)
# Requirement already satisfied: filelock in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pelle\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\pelle\appdata\roaming\python\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pelle\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# diffusion_pytorch_model.safetensors:  70%|#######   | 1.21G/1.72G [00:00<?, ?B/s]
# c:\Users\Pelle\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Pelle\.cache\huggingface\hub\models--dreamlike-art--dreamlike-photoreal-2.0. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x768>
